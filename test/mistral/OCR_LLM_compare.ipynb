# %%
from mistralai import Mistral
from dotenv import load_dotenv
import os
load_dotenv(".env")

MISTRAL_API_KEY = os.getenv("MISTRAL_API_KEY")

# %%
client = Mistral(api_key=MISTRAL_API_KEY )

uploaded_pdf_1 = client.files.upload(
    file={
        "file_name": "uploaded_file.pdf",
        "content": open("data/Invoice-900F4466-0001.pdf", "rb"),
    },
    purpose="ocr"
) 

uploaded_pdf_2 = client.files.upload(
    file={
        "file_name": "uploaded_file.pdf",
        "content": open("data/Invoice-900F4466-0001 - Copy (1).pdf", "rb"),
    },
    purpose="ocr"
)

# %%
retrieved_file_1 = client.files.retrieve(file_id=uploaded_pdf_1.id)
print(retrieved_file_1)

signed_url_1 = client.files.get_signed_url(file_id=uploaded_pdf_1.id)

ocr_response_1 = client.ocr.process(
    model="mistral-ocr-latest",
    document={
        "type": "document_url",
        "document_url": signed_url_1.url,
    }
)

print(ocr_response_1)
# Out:
# id='a47c5111-0a1c-446f-b66f-75acf982fc27' object='file' size_bytes=36675 created_at=1745142731 filename='uploaded_file.pdf' purpose='ocr' sample_type='ocr_input' source='upload' deleted=False num_lines=None
# ...

# %%
retrieved_file_2 = client.files.retrieve(file_id=uploaded_pdf_2.id)
print(retrieved_file_2)

signed_url_2 = client.files.get_signed_url(file_id=uploaded_pdf_2.id)

ocr_response_2 = client.ocr.process(
    model="mistral-ocr-latest",
    document={
        "type": "document_url",
        "document_url": signed_url_2.url,
    }
)

print(ocr_response_2)
# Out:
# id='9076bdd5-ee25-4acf-8df8-7b77b59195f7' object='file' size_bytes=41677 created_at=1745142732 filename='uploaded_file.pdf' purpose='ocr' sample_type='ocr_input' source='upload' deleted=False num_lines=None
# ...

# %%
uploaded_pdf_3 = client.files.upload(
    file={
        "file_name": "uploaded_file.pdf",
        "content": open("data/Invoice-900F4466-0001 - Copy (2).pdf", "rb"),
    },
    purpose="ocr"
) 

retrieved_file_3 = client.files.retrieve(file_id=uploaded_pdf_3.id)
print(retrieved_file_3)

signed_url_3 = client.files.get_signed_url(file_id=uploaded_pdf_3.id)

ocr_response_3 = client.ocr.process(
    model="mistral-ocr-latest",
    document={
        "type": "document_url",
        "document_url": signed_url_3.url,
    }
)

print(ocr_response_3)
# Out:
# id='3ad73426-d5aa-40ca-90c5-7705469a99a7' object='file' size_bytes=49216 created_at=1745148332 filename='uploaded_file.pdf' purpose='ocr' sample_type='ocr_input' source='upload' deleted=False num_lines=None
# ...

# %%
ocr_response_2.pages[0].markdown
# Out:
# '# Invoice \n\n## Invoice number 901 F 44660001\n\nDate of issue April 5, 2025\nDate due April 5, 2025\n\n## Deep Infra Inc.\n\n2625 Middlefield Road\n\\#460\nPalo Alto, California 94306\nUnited States\n+1 206-658-5586\nstripe@deepinfra.com\n\n## Bill to\n\nNGUYEN PHUOC NGUYEN PHUC\nVietnam\nnguyenphuc100402@gmail.com\n\n## \\$3.00 USD due April 9, 2025\n\nPay online\n\n| Description | Qty | Unit price | Amount |\n| :-- | :--: | :--: | :--: |\n| Pre-pay for inference | 1 | $\\$ 3.00$ | $\\$ 3.00$ |\n| Subtotal |  |  | $\\$ 3.00$ |\n| Total |  |  | $\\$ 3.00$ |\n| Amount due |  |  | $\\$ 3.00$ USD |\n\n## Pay $\\$ 3.00$ with a bank transfer\n\nBank transfers can take up to two business days. To pay via bank transfer, transfer funds using the following bank information.\n\n| Bank name | Wells Fargo |\n| :-- | :-- |\n| Routing number 121000148 |  |\n| Account number | 40630204921688775 |\n| SWIFT code | WFBIUS6SXXX |\n| Reference | 901F44660001 |'

# %%
from pydantic import BaseModel, Field
from typing import List, Optional, Literal, Union
import json

class Replacement(BaseModel):
    original: str = Field(..., description="The base text from first PDF")
    text: str 
    type:  Literal["replace"]
    
class Addition(BaseModel):
    text: str
    type: Literal["add"]
    
class Deletion(BaseModel):
    text: str
    type:  Literal["delete"]
    
class Page(BaseModel):
    page_number: int
    modify_detection: Optional[List[Union['Replacement', 'Addition', 'Deletion']]] 

class Detection_Result(BaseModel):
    page: List[Page]
    modified: Literal["yes", "no"] = Field(..., description="Yes if detect any different, no if not")

# %%
# Specify model
model = "mistral-small-latest"

# Define the messages for the chat
messages = [
    {
        "role": "system",
        "content": [
            {
                "type": "text",
                "text": """
**Role**: You are a good PDF comparer:

**Detailed Mission**:
- You will receive input text about 2 PDF - all extracted text, in each page.
- These 2 PDF are expected to be the same, but the second one is received from customer, so they could change some thing - what you will detect. 
- You need to detect any different in 3 type: replace, add, delete if exist in each page, if no, leave None. Please follow the given structured to answer.

**Attention**:
- Because the second PDF is scanned, so the overal position may change a bit - lead to Text Extract may not in order from the first, but this should be just a slight change, so do not strict much about the position
- You should care about meaning, sentence level

"""
            }
        ]
    },
    {
        "role": "user",
        "content": [
            {
                "type": "text",
                "text": f"""**This is page 1**: 
- First PDF in Markdown \n\n \"{ocr_response_1.pages[0].markdown}\" 
- Second PDF in Markdown \n\n \"{ocr_response_2.pages[0].markdown}\"  
                        
                        
**This is page 2**:
- First PDF in Markdown \n\n \"{ocr_response_1.pages[0].markdown}\" 
- Second PDF in Markdown \n\n \"{ocr_response_3.pages[0].markdown}\"  """
            }
        ]
    }
]

# Get the chat response
chat_response = client.chat.parse(
    model=model,
    messages=messages,
    response_format=Detection_Result
)

# Print the content of the response
print(chat_response.choices[0].message.content)

# Output: 
# The last sentence in the document is:\n\n\"Zaremba, W., Sutskever, I., and Vinyals, O. Recurrent neural network regularization. arXiv:1409.2329, 2014.
# Out:
# {
#   "page": [
#     {
#       "page_number": 1,
#       "modify_detection": null
#     },
#     {
#       "page_number": 2,
#       "modify_detection": [
#         {
#           "original": "Invoice number 900F4466-0001",
#           "text": "Invoice number 901F44660001",
#           "type": "replace"
#         },
#         {
#           "original": "Date of issue April 9, 2025",
#           "text": "Date of issue April 5, 2025",
#           "type": "replace"
#         },
#         {
#           "original": "Date due April 9, 2025",
#           "text": "Date due April 5, 2025",
#           "type": "replace"
#         },
#         {
#           "original": "2625 Middlefield Road\n#460\nPalo Alto, California 94306\nUnited States",
#           "text": "+1 206-658-5586 #460\nstripe@deepinfra.com\n2625 Middlefield Road\nPalo Alto, California 94306\nUnited States",
#           "type": "replace"
#         },
#         {
#           "original": "$2.00 USD due April 9, 2025",
# ...

# %% [markdown]
# ## Only LLM

# %%
import os
from mistralai import Mistral

# Specify model
model = "mistral-small-latest"

# Initialize the Mistral client
client = Mistral(api_key=MISTRAL_API_KEY)

#If local document, upload and retrieve the signed url
uploaded_pdf_1 = client.files.upload(
    file={
        "file_name": "uploaded_file.pdf",
        "content": open("data/Invoice-900F4466-0001.pdf", "rb"),
    },
    purpose="ocr"
)
signed_url_1 = client.files.get_signed_url(file_id=uploaded_pdf_1.id)


uploaded_pdf_2 = client.files.upload(
    file={
        "file_name": "uploaded_file.pdf",
        "content": open("data/Invoice-900F4466-0001 - Copy (1).pdf", "rb"),
    },
    purpose="ocr"
)
signed_url_2 = client.files.get_signed_url(file_id=uploaded_pdf_2.id)


uploaded_pdf_3 = client.files.upload(
    file={
        "file_name": "uploaded_file.pdf",
        "content": open("data/Invoice-900F4466-0001 - Copy (2).pdf", "rb"),
    },
    purpose="ocr"
)
signed_url_3 = client.files.get_signed_url(file_id=uploaded_pdf_3.id)

# Define the messages for the chat
messages = [
    {
        "role": "system",
        "content": [
            {
                "type": "text",
                "text": """
**Role**: You are a good PDF comparer:

**Detailed Mission**:
- You will receive input text about 2 PDF - all extracted text, in each page.
- These 2 PDF are expected to be the same, but the second one is received from customer, so they could change some thing - what you will detect. 
- You need to detect any different in 3 type: replace, add, delete if exist in each page, if no, leave None. Please follow the given structured to answer.

**Attention**:
- Because the second PDF is scanned, so the overal position may change a bit - lead to Text Extract may not in order from the first, but this should be just a slight change, so do not strict much about the position
- You should care about meaning, sentence level

"""
            }
        ]
    },
    {
        "role": "user",
        "content": [
            {
                "type": "text",
                "text": "This is the first PDF"
            },
            {
                "type": "document_url",
                #"document_url": "https://arxiv.org/pdf/1805.04770"
                "document_url": signed_url_1.url
            }
        ]
    },
    {
        "role": "user",
        "content": [
            {
                "type": "text",
                "text": "This is the second PDF"
            },
            {
                "type": "document_url",
                #"document_url": "https://arxiv.org/pdf/1805.04770"
                "document_url": signed_url_1.url
            }
        ]
    }
]

# Get the chat response
chat_response = client.chat.parse(
    model=model,
    messages=messages,
    response_format=Detection_Result
)

# Print the content of the response
print(chat_response.choices[0].message.content)

# Output: 
# The last sentence in the document is:\n\n\"Zaremba, W., Sutskever, I., and Vinyals, O. Recurrent neural network regularization. arXiv:1409.2329, 2014.
# Out:
# {
#   "page": [
#     {
#       "page_number": 1,
#       "modify_detection": null
#     }
#   ],
#   "modified": "no"
# }
